# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5])

# %%
print(arr.dtype)
# Out:
# int32

# %%
arr.astype("float64")
# Out:
# array([1., 2., 3., 4., 5.])

# %%
arr.dtype
# Out:
# dtype('int32')

# %%
arr2= np.array([1,2,3,4,5],dtype = "float64")
print(arr2.dtype)
print(arr2)
# Out:
# float64
# [1. 2. 3. 4. 5.]

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr.dtype
# Out:
# dtype('int32')

# %%
arr_large = np.array([20000,40000,500000],dtype = np.int64)
arr_large.dtype
# Out:
# dtype('int64')

# %%
arr_small = arr_large.astype(np.int32)

# %%
print(arr_small)
# Out:
# [ 20000  40000 500000]

# %%
print(arr_small.dtype)
# Out:
# int32

# %%
arr2.nbytes
# Out:
# 40

# %%
arr.nbytes
# Out:
# 20

# %%
#for finding memory usage 
arr_first = np.array([1,2,3,5,5],dtype = 'int64')
arr_second = np.array([6,7,8,9,10],dtype = 'int32')
print(arr_first.nbytes)
print(arr_second.nbytes)
# Out:
# 40
# 20

# %%
#complex number 
arr_complex = np.array([1+4j,4+6j],dtype = 'complex128')
arr_complex
# Out:
# array([1.+4.j, 4.+6.j])

# %%
Arr = np.array([1+2j,2+3j,4+6j],dtype = 'complex64')

# %%
print(Arr)
# Out:
# [1.+2.j 2.+3.j 4.+6.j]

# %%
arr = np.array([{'a': 1}, [1, 2, 3], 'hello'], dtype=object)
print(arr)
# Out:
# [{'a': 1} list([1, 2, 3]) 'hello']
