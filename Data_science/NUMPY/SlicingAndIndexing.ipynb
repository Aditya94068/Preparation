# %%
import numpy as np

# %%
arr = np.array([[1,2,3],[4,5,6],[6,7,8],[9,10,11]])
arr
# Out:
# array([[ 1,  2,  3],
#        [ 4,  5,  6],
#        [ 6,  7,  8],
#        [ 9, 10, 11]])

# %%
arr[0]
# Out:
# array([1, 2, 3])

# %%
arr[3]
# Out:
# array([ 9, 10, 11])

# %%
flat = arr.flatten()

# %%
flat
# Out:
# array([ 1,  2,  3,  4,  5,  6,  6,  7,  8,  9, 10, 11])

# %%
flat[9]
# Out:
# 9

# %%
flat[4:5]
# Out:
# array([5])

# %%
flat[:5]
# Out:
# array([1, 2, 3, 4, 5])

# %%
flat[5:]
# Out:
# array([ 6,  6,  7,  8,  9, 10, 11])

# %%
flat[-1]
# Out:
# 11

# %%
flat[::2]
# Out:
# array([ 1,  3,  5,  6,  8, 10])

# %%
flat[::3]
# Out:
# array([1, 4, 6, 9])

# %%
arr
# Out:
# array([[ 1,  2,  3],
#        [ 4,  5,  6],
#        [ 6,  7,  8],
#        [ 9, 10, 11]])

# %%
flat
# Out:
# array([ 1,  2,  3,  4,  5,  6,  6,  7,  8,  9, 10, 11])

# %%
b = flat[3:8]
print(b)
# Out:
# [4 5 6 6 7]

# %%
b[0]
# Out:
# 4

# %%
b[0] = 55667

# %%
print(b)
# Out:
# [55667     5     6     6     7]

# %%
print(flat)
# Out:
# [    1     2     3 55667     5     6     6     7     8     9    10    11]

# %%
b = flat[5:8].copy()#This is not a slicing because we are using copy method 
                    #insted of slicing so thatswhy the b memory size
                    #array is created

# %%
print(b)
# Out:
# [6 6 7]

# %%
print(flat)
# Out:
# [    1     2     3 55667     5     6     6     7     8     9    10    11]

# %%
b[0] = 53595

# %%
print(b)
# Out:
# [53595     6     7]

# %%
print(flat)
# Out:
# [    1     2     3 55667     5     6     6     7     8     9    10    11]

# %%
Array = np.array([10,20,30,40,50])

# %%
print(Array)
# Out:
# [10 20 30 40 50]

# %%
Array[[0,2,4]]
# Out:
# array([10, 30, 50])

# %%
Array[Array>30]
# Out:
# array([40, 50])
