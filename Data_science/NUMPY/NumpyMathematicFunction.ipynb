# %%
# Numpy Common Use Mathmatical function
# np.mean(arr)
# np.std(arr)
# np.var(arr) for finding Variance
# np.min(arr)
# np.max(arr)
# np.sum(arr)
# np.diff(arr)
# np.prod(arr)
# np.median(arr)
# np.percentile(arr, 50)  # For the 50th percentile (median)
# np.argmin(arr)
# np.argmax(arr)
# np.corrcoef(arr1, arr2)
# np.unique(arr)
# np.cumsum(arr)
# np.linspace(0, 10, 5)  # 5 numbers from 0 to 10
# np.log(arr)
# np.exp(arr)

# %%
import numpy as np
arr = np.array([1,22,12,64,3,32,5,1,3,1])
arr2 = np.array([2,43,64,1,4,5])

# %%
np.mean(arr)
# Out:
# 26.2

# %%
np.std(arr)
# Out:
# 21.525798475317934

# %%
np.var(arr)
# Out:
# 463.35999999999996

# %%
np.max(arr)
# Out:
# 64

# %%
np.min(arr)
# Out:
# 1

# %%
np.sum(arr)
# Out:
# 131

# %%
np.diff(arr)
# Out:
# array([ 21, -10,  52, -32])

# %%
np.prod(arr)
# Out:
# 540672

# %%
np.median(arr)
# Out:
# 22.0

# %%
np.percentile(arr,64)
# Out:
# 27.6

# %%
np.argmin(arr)
# Out:
# 0

# %%
np.argmax(arr)
# Out:
# 3

# %%
np.corrcoef(arr,arr2)
# Out:
# array([[ 1.        , -0.38595294],
#        [-0.38595294,  1.        ]])

# %%
np.unique(arr)
# Out:
# array([ 1,  3,  5, 12, 22, 32, 64])

# %%
np.cumsum(arr)
# Out:
# array([  1,  23,  35,  99, 131, 136, 137, 140, 141])

# %%
np.linspace(0,10,5)
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# %%
np.log(arr)
# Out:
# array([0.        , 3.09104245, 2.48490665, 4.15888308, 1.09861229,
#        3.4657359 , 1.60943791, 0.        , 1.09861229, 0.        ])

# %%
np.exp(arr)
# Out:
# array([2.71828183e+00, 3.58491285e+09, 1.62754791e+05, 6.23514908e+27,
#        2.00855369e+01, 7.89629602e+13, 1.48413159e+02, 2.71828183e+00,
#        2.00855369e+01, 2.71828183e+00])
