# %%
import pandas as pd

# %%
employees = pd.DataFrame({
    "EmpID": [1, 2, 3],
    "Name": ["Alice", "Bob", "Charlie"],
    "DeptID": [10, 20, 30]
})

departments = pd.DataFrame({
    "DeptID": [10, 20, 40],
    "DeptName": ["HR", "Engineering", "Marketing"]
})

# %%
employees
# Out:
#    EmpID     Name  DeptID
# 0      1    Alice      10
# 1      2      Bob      20
# 2      3  Charlie      30

# %%
departments
# Out:
#    DeptID     DeptName
# 0      10           HR
# 1      20  Engineering
# 2      40    Marketing

# %%
# pd.merge(employees, departments, on="DeptID")

pd.merge(employees,departments,on = "DeptID")
# Out:
#    EmpID   Name  DeptID     DeptName
# 0      1  Alice      10           HR
# 1      2    Bob      20  Engineering

# %%
# pd.merge(employees, departments, on="DeptID", how="left")
pd.merge(employees,departments,on = "DeptID",how = "left")
# Out:
#    EmpID     Name  DeptID     DeptName
# 0      1    Alice      10           HR
# 1      2      Bob      20  Engineering
# 2      3  Charlie      30          NaN

# %%
# pd.merge(employees, departments, on="DeptID", how="right")
pd.merge(employees,departments,on = "DeptID",how = "right")
# Out:
#    EmpID   Name  DeptID     DeptName
# 0    1.0  Alice      10           HR
# 1    2.0    Bob      20  Engineering
# 2    NaN    NaN      40    Marketing

# %%
# pd.merge(employees, departments, on="DeptID", how="outer")

pd.merge(employees,departments,on = "DeptID",how = "outer")
# Out:
#    EmpID     Name  DeptID     DeptName
# 0    1.0    Alice      10           HR
# 1    2.0      Bob      20  Engineering
# 2    3.0  Charlie      30          NaN
# 3    NaN      NaN      40    Marketing

# %%
df1 = pd.DataFrame({"Name": ["Alice", "Bob"]})
df2 = pd.DataFrame({"Name": ["Charlie", "David"]})

# %%
df1
# Out:
#     Name
# 0  Alice
# 1    Bob

# %%
df2
# Out:
#       Name
# 0  Charlie
# 1    David

# %%
pd.concat([df1, df2])
# Out:
#       Name
# 0    Alice
# 1      Bob
# 0  Charlie
# 1    David

# %%
pd.concat([df1,df2],axis = 1)
# Out:
#     Name     Name
# 0  Alice  Charlie
# 1    Bob    David

# %%
# df1 = pd.DataFrame({"ID": [1, 2]})
# df2 = pd.DataFrame({"Score": [90, 80]})

df1 = pd.DataFrame({"ID":[10,20,30]})
df2 = pd.DataFrame({"Score":[90,56,80]})

# %%
df1
# Out:
#    ID
# 0  10
# 1  20
# 2  30

# %%
df2
# Out:
#    Score
# 0     90
# 1     56
# 2     80

# %%
pd.concat([df1, df2], axis=1)
# Out:
#    ID  Score
# 0  10     90
# 1  20     56
# 2  30     80

# %%
df1 = pd.DataFrame({"Name": ["Alice", "Bob"],"Score":[356,768]})
df2 = pd.DataFrame({"Name": ["Charlie", "David"],"Age":[65,76]})

# %%
df1
# Out:
#     Name  Score
# 0  Alice    356
# 1    Bob    768

# %%
df2
# Out:
#       Name  Age
# 0  Charlie   65
# 1    David   76

# %%
pd.concat([df1, df2], axis=1)
# Out:
#     Name  Score     Name  Age
# 0  Alice    356  Charlie   65
# 1    Bob    768    David   76
