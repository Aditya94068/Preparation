# %%
import pandas as pd

# %%
df = pd.read_csv("dataCleaning.csv")

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12/11/2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 7    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
#this statement is used to check null values
# df.isnull()              # True for NaNs
# df.isnull().sum()        # Count missing per column

# %%
df.isnull()
# Out:
#     Name    Age   City  Gender  Email  Join Date
# 0  False  False  False   False  False      False
# 1  False   True  False   False  False      False
# 2  False  False  False   False  False      False
# 3  False   True  False   False  False      False
# 4  False  False  False   False  False      False
# 5   True  False  False   False  False       True
# 6  False  False  False   False  False      False
# 7  False  False  False   False  False      False
# 8  False   True  False   False  False      False

# %%
df.isnull().sum()
# Out:
# Name         1
# Age          3
# City         0
# Gender       0
# Email        0
# Join Date    1
# dtype: int64

# %%
#this statement is used to drop a specific row and column where the missing value is found
# df.dropna()              # Drop rows with *any* missing values
# df.dropna(axis=1)        # Drop columns with missing values

# %%
df.dropna()
# Out:
#     Name   Age         City Gender              Email   Join Date
# 0  Alice  25.0     New York      F  alice@example.com    1/5/2021
# 2    Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4  David  22.0       Mumbai      M  david@example.com  12/11/2019
# 6  Alice  25.0     New York      F  alice@example.com    1/5/2021
# 7  Alice  25.0     New York      F  alice@example.com    1/5/2021

# %%
df.dropna(axis = 1)
# Out:
#           City Gender              Email
# 0     New York      F  alice@example.com
# 1        Delhi      M    charlie@example
# 2  Los Angeles      M    bob@example.com
# 3        Delhi      M    charlie@example
# 4       Mumbai      M  david@example.com
# 5        Delhi      F     eve@domain.com
# 6     New York      F  alice@example.com
# 7     New York      F  alice@example.com
# 8        Delhi      M    charlie@example

# %%
# This command is used for filling missing data
# df.fillna(0)                     # Replace NaN with 0

#below command work same 
# df["Age"].fillna(df["Age"].mean())  # Replace with mean
# df.ffill()      # Forward fill
# df.bfill()      # Backward fill

# %%
df.fillna(0)
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 1  Charlie   0.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   0.0        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12/11/2019
# 5        0  28.0        Delhi      F     eve@domain.com           0
# 6    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 7    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 8  Charlie   0.0        Delhi      M    charlie@example  20-07-2021

# %%
# df["Age"].fillna(df["Age"].mean())  # Replace with mean
df["Age"].fillna(df["Age"].mean())
# Out:
# 0    25.000000
# 1    25.833333
# 2    30.000000
# 3    25.833333
# 4    22.000000
# 5    28.000000
# 6    25.000000
# 7    25.000000
# 8    25.833333
# Name: Age, dtype: float64

# %%
df.ffill()
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 1  Charlie  25.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie  30.0        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12/11/2019
# 5    David  28.0        Delhi      F     eve@domain.com  12/11/2019
# 6    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 7    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 8  Charlie  25.0        Delhi      M    charlie@example  20-07-2021

# %%
df.bfill()
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 1  Charlie  30.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie  22.0        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12/11/2019
# 5    Alice  28.0        Delhi      F     eve@domain.com    1/5/2021
# 6    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 7    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
#this is valid but not in future version of pandas
# df.fillna(method="ffill")
# df.fillna(method = "bfill")

# %%
#This method is used for finding duplictaes and  droping duplicates
# df.duplicated()          # True for duplicates
# df.drop_duplicates()     # Remove duplicate rows

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4    David  22.0       Mumbai      M  david@example.com  12/11/2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN

# %%
#checking based on specific colunm
# df.duplicated(subset=["Name", "Age"])

# %%
df.duplicated(subset = ["Name","Age"])
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12/11/2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 7    Alice  25.0     New York      F  alice@example.com    1/5/2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
#string Operations
# df["Name"].str.lower() # Converts all names to lowercase.
# df["City"].str.contains("delhi", case=False) # Checks if 'delhi' is in the city name, case-insensitive.
# df["Email"].str.split("@") # Outputs a pandas Series where each element is a list of strings (the split parts). This is where a Python list comes into play, but the outer object is still a pandas Series.

# %%
df["Name"].str.lower()
# Out:
# 0      alice
# 1    charlie
# 2        bob
# 3    charlie
# 4      david
# 5        NaN
# 6      alice
# 7      alice
# 8    charlie
# Name: Name, dtype: object

# %%
df["Name"].str.upper()
# Out:
# 0      ALICE
# 1    CHARLIE
# 2        BOB
# 3    CHARLIE
# 4      DAVID
# 5        NaN
# 6      ALICE
# 7      ALICE
# 8    CHARLIE
# Name: Name, dtype: object

# %%
df["City"].str.contains("delhi",case = False)
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7    False
# 8     True
# Name: City, dtype: bool

# %%
df["Email"].str.split("@")
# Out:
# 0    [alice, example.com]
# 1      [charlie, example]
# 2      [bob, example.com]
# 3      [charlie, example]
# 4    [david, example.com]
# 5       [eve, domain.com]
# 6    [alice, example.com]
# 7    [alice, example.com]
# 8      [charlie, example]
# Name: Email, dtype: object

# %%
#Type Conversion
# df["Age"] = df["Age"].astype(int)
# df["Date"] = pd.to_datetime(df["Date"])
# df["Category"] = df["Category"].astype("category")

# %%
df2 = df.dropna().copy()

# %%
df2
# Out:
#     Name   Age         City  Gender              Email   Join Date
# 0  Alice  25.0     New York  Female  alice@example.com    1/5/2021
# 2    Bob  30.0  Los Angeles    Male    bob@example.com  15-06-2020
# 4  David  22.0       Mumbai    Male  david@example.com  12/11/2019
# 6  Alice  25.0     New York  Female  alice@example.com    1/5/2021
# 7  Alice  25.0     New York  Female  alice@example.com    1/5/2021

# %%
df2["Age"]= df2["Age"].astype(int)

# %%
df2
# Out:
#     Name  Age         City  Gender              Email   Join Date
# 0  Alice   25     New York  Female  alice@example.com    1/5/2021
# 2    Bob   30  Los Angeles    Male    bob@example.com  15-06-2020
# 4  David   22       Mumbai    Male  david@example.com  12/11/2019
# 6  Alice   25     New York  Female  alice@example.com    1/5/2021
# 7  Alice   25     New York  Female  alice@example.com    1/5/2021

# %%
#Using Lambda Function 
# df["Age Group"] = df["Age"].apply(lambda x: "Adult" if x >= 18 else "Minor")

# %%
#Applying Function ,use apply() keyword
# .apply() → Apply any function to rows or columns
#Using Normal function 
def isminor(x):
    if(x>=25):
        return "Adult"
    else:
        return "Minor"
df2["Age Group"] = df2["Age"].apply(isminor)

# %%
df2
# Out:
#     Name  Age         City Gender              Email   Join Date Age Group
# 0  Alice   25     New York    NaN  alice@example.com    1/5/2021     Adult
# 2    Bob   30  Los Angeles    NaN    bob@example.com  15-06-2020     Adult
# 4  David   22       Mumbai    NaN  david@example.com  12/11/2019     Minor
# 6  Alice   25     New York    NaN  alice@example.com    1/5/2021     Adult
# 7  Alice   25     New York    NaN  alice@example.com    1/5/2021     Adult

# %%
#Applying Map Function 
# .map() → Element-wise mapping for Series
gender_map = {"M": "Male", "F": "Female"}
df["Gender"] = df["Gender"].map(gender_map)

# %%
# gender_map = {"M":"Male","F":"Female","O":"Others"}
# df["Gender"] = df["Gender"].map(gender_map)

# %%
df
# Out:
#       Name   Age         City  Gender              Email   Join Date
# 0    Alice  25.0     New York  Female  alice@example.com    1/5/2021
# 1  Charlie   NaN        Delhi    Male    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles    Male    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi    Male    charlie@example  20-07-2021
# 4    David  22.0       Mumbai    Male  david@example.com  12/11/2019
# 5      NaN  28.0        Delhi  Female     eve@domain.com         NaN
# 6    Alice  25.0     New York  Female  alice@example.com    1/5/2021
# 7    Alice  25.0     New York  Female  alice@example.com    1/5/2021
# 8  Charlie   NaN        Delhi    Male    charlie@example  20-07-2021

# %%
df2
# Out:
#     Name   Age         City  Gender              Email   Join Date
# 0  Alice  25.0     New York  Female  alice@example.com    1/5/2021
# 2    Bob  30.0  Los Angeles    Male    bob@example.com  15-06-2020
# 4  David  22.0       Mumbai    Male  david@example.com  12/11/2019
# 6  Alice  25.0     New York  Female  alice@example.com    1/5/2021
# 7  Alice  25.0     New York  Female  alice@example.com    1/5/2021

# %%
gender_map = {"Male" : "M","Female":"F"}
df2["Gender"] = df2["Gender"].map(gender_map)

# %%
df2
# Out:
#     Name   Age         City Gender              Email   Join Date
# 0  Alice  25.0     New York      F  alice@example.com    1/5/2021
# 2    Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4  David  22.0       Mumbai      M  david@example.com  12/11/2019
# 6  Alice  25.0     New York      F  alice@example.com    1/5/2021
# 7  Alice  25.0     New York      F  alice@example.com    1/5/2021

# %%
df["City"].replace({"Delhi": "New Delhi", "Mumbai": "New Mumbai"})
# Out:
# 0       New York
# 1      New Delhi
# 2    Los Angeles
# 3      New Delhi
# 4     New Mumbai
# 5      New Delhi
# 6       New York
# 7       New York
# 8      New Delhi
# Name: City, dtype: object

# %%
df
# Out:
#       Name   Age         City  Gender              Email   Join Date
# 0    Alice  25.0     New York  Female  alice@example.com    1/5/2021
# 1  Charlie   NaN        Delhi    Male    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles    Male    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi    Male    charlie@example  20-07-2021
# 4    David  22.0       Mumbai    Male  david@example.com  12/11/2019
# 5      NaN  28.0        Delhi  Female     eve@domain.com         NaN
# 6    Alice  25.0     New York  Female  alice@example.com    1/5/2021
# 7    Alice  25.0     New York  Female  alice@example.com    1/5/2021
# 8  Charlie   NaN        Delhi    Male    charlie@example  20-07-2021

# %%
df2.dtypes
# Out:
# Name          object
# Age          float64
# City          object
# Gender        object
# Email         object
# Join Date     object
# dtype: object
