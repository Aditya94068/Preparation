# %%
import pandas as pd

# %%
s1 = pd.Series([12,33,53,65,75])

# %%
print(s1)
# Out:
# 0    12
# 1    33
# 2    53
# 3    65
# 4    75
# dtype: int64

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s2 = pd.Series([43,54,65,76,87],index = ["Aditya","Rahul","Kunal","Aman","John"])

# %%
print(s2)
# Out:
# Aditya    43
# Rahul     54
# Kunal     65
# Aman      76
# John      87
# dtype: int64

# %%
s2["Rahul"]
# Out:
# 54

# %%
s2["Aman"]
# Out:
# 76

# %%
data = {
    "Name":["Aditya","John","Rohan"],
    "Age" :[20,54,65],
    "City": ["Nashik","Florida","Pune"]
}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#      Name  Age     City
# 0  Aditya   20   Nashik
# 1    John   54  Florida
# 2   Rohan   65     Pune
