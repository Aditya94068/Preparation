# %%
import pandas as pd

# %%
df = pd.read_csv("data1.csv")

# %%
#Selecting Column Structure
# df["column_name"]        # Single column (as Series)
# df[["col1", "col2"]]     # Multiple columns (as DataFrame)

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 1                    565   6.0
# 2                   2024   8.4
# 3                    431   5.6
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# 8                    318   7.0
# 9                    266   5.9
# 10                   201   6.1
# 11                   342   8.2

# %%
df['Actor']
# Out:
# 0         Shah Rukh Khan
# 1            Salman Khan
# 2             Aamir Khan
# 3          Ranbir Kapoor
# 4          Ranveer Singh
# 5     Ayushmann Khurrana
# 6          Rajkummar Rao
# 7         Hrithik Roshan
# 8           Akshay Kumar
# 9          Kartik Aaryan
# 10          Varun Dhawan
# 11         Vicky Kaushal
# Name: Actor, dtype: object

# %%
df[["Actor","Year"]]
# Out:
#                  Actor  Year
# 0       Shah Rukh Khan  2023
# 1          Salman Khan  2017
# 2           Aamir Khan  2016
# 3        Ranbir Kapoor  2022
# 4        Ranveer Singh  2018
# 5   Ayushmann Khurrana  2018
# 6        Rajkummar Rao  2018
# 7       Hrithik Roshan  2019
# 8         Akshay Kumar  2019
# 9        Kartik Aaryan  2022
# 10        Varun Dhawan  2017
# 11       Vicky Kaushal  2019

# %%
#Selecting row by index
# df.loc[0]                # First row (by label)
# df.iloc[0]               # First row (by position)

# %%
df.loc[]
# Out:
# Actor                   Shah Rukh Khan
# Film                           Pathaan
# Year                              2023
# Genre                           Action
# BoxOffice(INR Crore)              1050
# IMDb                               7.2
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# Actor                   Shah Rukh Khan
# Film                           Pathaan
# Year                              2023
# Genre                           Action
# BoxOffice(INR Crore)              1050
# IMDb                               7.2
# Name: 0, dtype: object

# %%
#Select Specific Row and Column [cell]
# df.loc[0, "Name"]        # Value at row 0, column 'Name'
# df.iloc[0, 1]            # Value at row 0, column at index 1

# %%
df.loc[1,"IMDb"]
# Out:
# 6.0

# %%
df.iloc[1,4]
# Out:
# 565

# %%
#Sliceing 
# df.loc[0:2, ["Name", "Age"]]   # Rows 0 to 2, selected columns
# df.iloc[0:2, 0:2]              # Rows and cols by index position

# %%
df.loc[0:5,["Actor","Film","Year","Genre"]]
# Out:
#                 Actor             Film  Year       Genre
# 0      Shah Rukh Khan          Pathaan  2023      Action
# 1         Salman Khan  Tiger Zinda Hai  2017      Action
# 2          Aamir Khan           Dangal  2016   Biography
# 3       Ranbir Kapoor       Brahmastra  2022     Fantasy
# 4       Ranveer Singh        Padmaavat  2018  Historical
# 5  Ayushmann Khurrana        Andhadhun  2018    Thriller

# %%
df.iloc[0:4,0:5]
# Out:
#             Actor             Film  Year      Genre  BoxOffice(INR Crore)
# 0  Shah Rukh Khan          Pathaan  2023     Action                  1050
# 1     Salman Khan  Tiger Zinda Hai  2017     Action                   565
# 2      Aamir Khan           Dangal  2016  Biography                  2024
# 3   Ranbir Kapoor       Brahmastra  2022    Fantasy                   431

# %%
#For Fast Accessing
# df.at[0, "Name"]       # Fast label-based access
# df.iat[0, 1]           # Fast position-based access

# %%
df.at[0,"Actor"]
# Out:
# 'Shah Rukh Khan'

# %%
df.iat[3,1]
# Out:
# 'Brahmastra'

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 1                    565   6.0
# 2                   2024   8.4
# 3                    431   5.6
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# 8                    318   7.0
# 9                    266   5.9
# 10                   201   6.1
# 11                   342   8.2

# %%
df[(df['Year']>2018) &( df['IMDb']>6)]
# Out:
#              Actor                      Film  Year   Genre  \
# 0   Shah Rukh Khan                   Pathaan  2023  Action
# 7   Hrithik Roshan                       War  2019  Action
# 8     Akshay Kumar                Good Newwz  2019  Comedy
# 11   Vicky Kaushal  Uri: The Surgical Strike  2019  Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 7                    475   6.5
# 8                    318   7.0
# 11                   342   8.2

# %%
df.query('Year>2019 and IMDb>6')
# Out:
#             Actor     Film  Year   Genre  BoxOffice(INR Crore)  IMDb
# 0  Shah Rukh Khan  Pathaan  2023  Action                  1050   7.2

# %%
IMDb  = 7.0
df.query("IMDb >@IMDb")
# Out:
#                  Actor                      Film  Year          Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023         Action
# 2           Aamir Khan                    Dangal  2016      Biography
# 5   Ayushmann Khurrana                 Andhadhun  2018       Thriller
# 6        Rajkummar Rao                     Stree  2018  Horror Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019         Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 2                   2024   8.4
# 5                    111   8.3
# 6                    180   7.5
# 11                   342   8.2

# %%
df.query("6.0<IMDb <=8.2")
# Out:
#              Actor                      Film  Year            Genre  \
# 0   Shah Rukh Khan                   Pathaan  2023           Action
# 4    Ranveer Singh                 Padmaavat  2018       Historical
# 6    Rajkummar Rao                     Stree  2018    Horror Comedy
# 7   Hrithik Roshan                       War  2019           Action
# 8     Akshay Kumar                Good Newwz  2019           Comedy
# 10    Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11   Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 4                    585   7.0
# 6                    180   7.5
# 7                    475   6.5
# 8                    318   7.0
# 10                   201   6.1
# 11                   342   8.2

# %%
df2 = df[['Actor','IMDb']].copy()

# %%
df2
# Out:
#                  Actor  IMDb
# 0       Shah Rukh Khan   7.2
# 1          Salman Khan   6.0
# 2           Aamir Khan   8.4
# 3        Ranbir Kapoor   5.6
# 4        Ranveer Singh   7.0
# 5   Ayushmann Khurrana   8.3
# 6        Rajkummar Rao   7.5
# 7       Hrithik Roshan   6.5
# 8         Akshay Kumar   7.0
# 9        Kartik Aaryan   5.9
# 10        Varun Dhawan   6.1
# 11       Vicky Kaushal   8.2

# %%
df2.loc[0,'Actor'] = "Aditya Vaishnav"

# %%
df2
# Out:
#                  Actor  IMDb
# 0      Aditya Vaishnav   7.2
# 1          Salman Khan   6.0
# 2           Aamir Khan   8.4
# 3        Ranbir Kapoor   5.6
# 4        Ranveer Singh   7.0
# 5   Ayushmann Khurrana   8.3
# 6        Rajkummar Rao   7.5
# 7       Hrithik Roshan   6.5
# 8         Akshay Kumar   7.0
# 9        Kartik Aaryan   5.9
# 10        Varun Dhawan   6.1
# 11       Vicky Kaushal   8.2

# %%
df2.iloc[1,0] = "Sumit"

# %%
df2
# Out:
#                  Actor  IMDb
# 0      Aditya Vaishnav   7.2
# 1                Sumit   6.0
# 2           Aamir Khan   8.4
# 3        Ranbir Kapoor   5.6
# 4        Ranveer Singh   7.0
# 5   Ayushmann Khurrana   8.3
# 6        Rajkummar Rao   7.5
# 7       Hrithik Roshan   6.5
# 8         Akshay Kumar   7.0
# 9        Kartik Aaryan   5.9
# 10        Varun Dhawan   6.1
# 11       Vicky Kaushal   8.2

# %%
df3 = df[['Actor','IMDb']].copy()

# %%
df3
# Out:
#                  Actor  IMDb
# 0       Shah Rukh Khan   7.2
# 1          Salman Khan   6.0
# 2           Aamir Khan   8.4
# 3        Ranbir Kapoor   5.6
# 4        Ranveer Singh   7.0
# 5   Ayushmann Khurrana   8.3
# 6        Rajkummar Rao   7.5
# 7       Hrithik Roshan   6.5
# 8         Akshay Kumar   7.0
# 9        Kartik Aaryan   5.9
# 10        Varun Dhawan   6.1
# 11       Vicky Kaushal   8.2

# %%
df4 = df.iloc[0:3 , 0:3]

# %%
df4
# Out:
#             Actor             Film  Year
# 0  Shah Rukh Khan          Pathaan  2023
# 1     Salman Khan  Tiger Zinda Hai  2017
# 2      Aamir Khan           Dangal  2016

# %%
df5 = df.iloc[0:6,0:4].copy()

# %%
df5
# Out:
#                 Actor             Film  Year       Genre
# 0      Shah Rukh Khan          Pathaan  2023      Action
# 1         Salman Khan  Tiger Zinda Hai  2017      Action
# 2          Aamir Khan           Dangal  2016   Biography
# 3       Ranbir Kapoor       Brahmastra  2022     Fantasy
# 4       Ranveer Singh        Padmaavat  2018  Historical
# 5  Ayushmann Khurrana        Andhadhun  2018    Thriller
